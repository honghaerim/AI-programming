# %%
print('저는 화진기업(주) 기업부설연구소에 근무중인 홍해림 선임연구원입니다. 나이는 40살이고 하는일은 임베디스 시스템이며 주로 모터제어쪽을 연구하고 있습니다.')
# Out:
# 저는 화진기업(주) 기업부설연구소에 근무중인 홍해림 선임연구원입니다. 나이는 40살이고 하는일은 임베디스 시스템이며 주로 모터제어쪽을 연구하고 있습니다.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-78c1d8c8-8057-4991-b2cd-22d9ca20a7e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78c1d8c8-8057-4991-b2cd-22d9ca20a7e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -la
# Out:
# total 3440
# drwxr-xr-x 1 root root    4096 Sep 12 04:46 .
# drwxr-xr-x 1 root root    4096 Sep 12 04:32 ..
# -rw-r--r-- 1 root root 3503395 Sep 12 04:46 20220824_135330.jpg
# drwxr-xr-x 4 root root    4096 Sep 10 13:28 .config
# drwxr-xr-x 1 root root    4096 Sep 10 13:28 sample_data
